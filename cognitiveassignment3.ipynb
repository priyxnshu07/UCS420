# %% [markdown]
# <a href="https://colab.research.google.com/github/priyxnshu07/UCS420/blob/main/cognitiveassignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q.1 Create a dataset as follow in the table.
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Creating the dataset
df = pd.read_csv('/content/drive/MyDrive/table.csv')


# Display
print(df)
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 0    1    Yes         Single          125000    No
# 1    2     No        Married          100000    No
# 2    3     No         Single           70000    No
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes
# 5    6     No        Married           60000    No
# 6    7    Yes       Divorced          220000    No
# 7    8     No         Single           85000   Yes
# 8    9     No        Married           75000    No
# 9   10     No         Single           90000   Yes

# %% [markdown]
# Q.2 From the above table that you have created, locate row 0, 4, 7 and 8 using DataFrame.

# %%
rows = df.loc[[0,4,7,8]]
print(rows)
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 0    1    Yes         Single          125000    No
# 4    5     No       Divorced           95000   Yes
# 7    8     No         Single           85000   Yes
# 8    9     No        Married           75000    No

# %% [markdown]
# Q.3 Navigate the DataFrame and do the following task for the table created in question 1:
# 1. Select row from index 3 to 7.
# 2. Select row from index 4 to 8, and column 2 to 4.
# 3. Select all rows with column index 1 to 3 (include index 3 during selection).

# %%
print(" row from index 3 to 7: ");
subset1 = df.iloc[3:8]
print(subset1)
print("")


print("row from index 4 to 8, and column 2 to 4: ");
subset2 = df.iloc[4:9,2:5]
print(subset2)
print("")


print("rows with column index 1 to 3 :  ");
subset3 = df.iloc[:,1:4]
print(subset3)
print("")
# Out:
#  row from index 3 to 7:
#    Tid Refund Marital Status  Taxable Income Cheat
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes
# 5    6     No        Married           60000    No
# 6    7    Yes       Divorced          220000    No
# 7    8     No         Single           85000   Yes
#
# row from index 4 to 8, and column 2 to 4:
#   Marital Status  Taxable Income Cheat
# 4       Divorced           95000   Yes
# 5        Married           60000    No
# 6       Divorced          220000    No
# 7         Single           85000   Yes
# 8        Married           75000    No
#
# rows with column index 1 to 3 :
#   Refund Marital Status  Taxable Income
# 0    Yes         Single          125000
# 1     No        Married          100000
# 2     No         Single           70000
# 3    Yes        Married          120000
# 4     No       Divorced           95000
# 5     No        Married           60000
# 6    Yes       Divorced          220000
# 7     No         Single           85000
# 8     No        Married           75000
# 9     No         Single           90000

# %% [markdown]
# Q.4 Read a csv file and display its first five rows.
# Note-: Download dataset from https://www.kaggle.com/datasets/uciml/iris)

# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/Iris.csv')
print(df1.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Q.5 From the csv file (uploaded in the Q.4) delete row 4, and delete column 3. Display the
# result.

# %%
df1 = df1.drop(4)
print(df1)

df1 = df1.drop(df1.columns[3], axis=1)
print(df1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 5      6            5.4           3.9            1.7           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 5       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [149 rows x 6 columns]
#       Id  SepalLengthCm  SepalWidthCm  PetalWidthCm         Species
# 0      1            5.1           3.5           0.2     Iris-setosa
# 1      2            4.9           3.0           0.2     Iris-setosa
# 2      3            4.7           3.2           0.2     Iris-setosa
# 3      4            4.6           3.1           0.2     Iris-setosa
# 5      6            5.4           3.9           0.4     Iris-setosa
# ..   ...            ...           ...           ...             ...
# 145  146            6.7           3.0           2.3  Iris-virginica
# 146  147            6.3           2.5           1.9  Iris-virginica
# 147  148            6.5           3.0           2.0  Iris-virginica
# 148  149            6.2           3.4           2.3  Iris-virginica
# 149  150            5.9           3.0           1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# Q.6 Create a sample dataset (employees.csv) containing information about employees in
# a company.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# WAP to determine the following using dataset in Q6:
# a) Shape (number of rows and columns) of the DataFrame.
# b) Summary of the DataFrame that includes the data types and non-null counts for
# each column.
# c) Generate descriptive statistics.
# d) Display the first 5 rows and last 3 rows of the dataset.
# e) Calculate the following statistics from the dataset:
# i. The average salary of employees.
# ii. The total bonus paid to all employees.
# iii. The youngest employee's age.
# iv. The highest performance rating.
#
# f) Sort the DataFrame by the Salary column in descending order.
# g) Add a new column that categorizes employees based on their performance rating:
#
# i. Excellent for ratings >= 4.5
# ii. Good for ratings >= 4.0 but < 4.5
# iii. Average for ratings < 4.0
# h) Identify missing values in the DataFrame.
# i) Rename the Employee_ID column to ID.
# j) Find all employees who:
#
# i. Have more than 5 years of experience.
# ii. Belong to the IT department.
#
# k) Modify the dataset by adding a new column, Tax, which deducts 10% of the
# Salary.
# l) Save the modified DataFrame (with added columns) to a new CSV file.

# %%
import pandas as pd
df2 = pd.read_csv('/content/drive/MyDrive/employees.csv')
print(df2)
# Out:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating
# 0   2020-03-15  Female   5000     4.5
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     3.5

# %%
print("a) Shape (number of rows and columns) of the DataFrame: ")
print("No of rows and columns = ", df2.shape)
# Out:
# a) Shape (number of rows and columns) of the DataFrame:
# No of rows and columns =  (5, 10)

# %%
print("b) Summary of the DataFrame that includes the data types and non-null counts for each column: ")
print(df2.info())
# Out:
# b) Summary of the DataFrame that includes the data types and non-null counts for each column:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          5 non-null      int64
#  1   Name                 5 non-null      object
#  2   Department           5 non-null      object
#  3   Age                  5 non-null      int64
#  4   Salary               5 non-null      int64
#  5   Years_of_Experience  5 non-null      int64
#  6   Joining_Date         5 non-null      object
#  7   Gender               5 non-null      object
#  8   Bonus                5 non-null      int64
#  9   Rating               5 non-null      float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 532.0+ bytes
# None

# %%
print("c) Generate descriptive statistics: ")
print(df2.describe())
# Out:
# c) Generate descriptive statistics:
#        Employee_ID        Age       Salary  Years_of_Experience   Bonus  \
# count     5.000000   5.000000      5.00000             5.000000     5.0
# mean    103.000000  34.000000  60000.00000             7.400000  5500.0
# std       1.581139   5.612486   7905.69415             3.847077  1000.0
# min     101.000000  28.000000  50000.00000             3.000000  4500.0
# 25%     102.000000  29.000000  55000.00000             4.000000  5000.0
# 50%     103.000000  34.000000  60000.00000             8.000000  5000.0
# 75%     104.000000  38.000000  65000.00000            10.000000  6000.0
# max     105.000000  41.000000  70000.00000            12.000000  7000.0
#
#          Rating
# count  5.000000
# mean   4.100000
# std    0.494975
# min    3.500000
# 25%    3.800000
# 50%    4.000000
# 75%    4.500000
# max    4.700000

# %%
print("d) Display the first 5 rows and last 3 rows of the dataset: ")
print("First 5 Rows: ")
print(df2.head())
print("Last 3 Rows: ")
print(df2.tail(3))
# Out:
# d) Display the first 5 rows and last 3 rows of the dataset:
# First 5 Rows:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating
# 0   2020-03-15  Female   5000     4.5
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     3.5
# Last 3 Rows:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     3.5

# %%
# e) Calculate the following statistics from the dataset:
print("i. The average salary of employees: ")
print(df2['Salary'].mean())

print("ii. The total bonus paid to all employees: ")
print(df2['Bonus'].sum())

print("iii. The youngest employee's age: ")
print(df2['Age'].min())

print("iv. The highest performance rating: ")
print(df2['Rating'].max())
# Out:
# i. The average salary of employees:
# 60000.0
# ii. The total bonus paid to all employees:
# 27500
# iii. The youngest employee's age:
# 28
# iv. The highest performance rating:
# 4.7

# %%
print("f) Sort the DataFrame by the Salary column in descending order: ")
print(df2.sort_values(by='Salary', ascending=False))
# Out:
# f) Sort the DataFrame by the Salary column in descending order:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 4          105   Edward      Sales   38   60000                   12
# 3          104    Diana  Marketing   28   55000                    3
# 0          101    Alice         HR   29   50000                    4
#
#   Joining_Date  Gender  Bonus  Rating
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 4   2010-11-25    Male   5000     3.5
# 3   2021-02-10  Female   4500     4.7
# 0   2020-03-15  Female   5000     4.5

# %%
# g) Add a new column that categorizes employees based on their performance rating:
def categorize_rating(rating):
    if rating >= 4.5:
        return 'Excellent'
    elif rating >= 4.0:
        return 'Good'
    else:
        return 'Average'
df2['Performance'] = df2['Rating'].apply(categorize_rating)
print(df2)
# Out:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating Performance
# 0   2020-03-15  Female   5000     4.5   Excellent
# 1   2017-07-19    Male   7000     4.0        Good
# 2   2013-06-01    Male   6000     3.8     Average
# 3   2021-02-10  Female   4500     4.7   Excellent
# 4   2010-11-25    Male   5000     3.5     Average

# %%
print("h) Identify missing values in the DataFrame: ")
print(df2.isnull().sum())
# Out:
# h) Identify missing values in the DataFrame:
# Employee_ID            0
# Name                   0
# Department             0
# Age                    0
# Salary                 0
# Years_of_Experience    0
# Joining_Date           0
# Gender                 0
# Bonus                  0
# Rating                 0
# Performance            0
# dtype: int64

# %%
print("i) Rename the Employee_ID column to ID: ")
df2 = df2.rename(columns={'Employee_ID': 'Emp_ID'}, inplace = False)
print(df2)
# Out:
# i) Rename the Employee_ID column to ID:
#    Emp_ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0     101    Alice         HR   29   50000                    4   2020-03-15
# 1     102      Bob         IT   34   70000                    8   2017-07-19
# 2     103  Charlie         IT   41   65000                   10   2013-06-01
# 3     104    Diana  Marketing   28   55000                    3   2021-02-10
# 4     105   Edward      Sales   38   60000                   12   2010-11-25
#
#    Gender  Bonus  Rating Performance
# 0  Female   5000     4.5   Excellent
# 1    Male   7000     4.0        Good
# 2    Male   6000     3.8     Average
# 3  Female   4500     4.7   Excellent
# 4    Male   5000     3.5     Average

# %%
# j) Find all employees who:
print("i. Have more than 5 years of experience: ")
print(df2[df2['Years_of_Experience'] > 5])

print("ii. Belong to the IT department: ")
print(df2[df2['Department'] == 'IT'])
# Out:
# i. Have more than 5 years of experience:
#    Emp_ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 1     102      Bob         IT   34   70000                    8   2017-07-19
# 2     103  Charlie         IT   41   65000                   10   2013-06-01
# 4     105   Edward      Sales   38   60000                   12   2010-11-25
#
#   Gender  Bonus  Rating Performance
# 1   Male   7000     4.0        Good
# 2   Male   6000     3.8     Average
# 4   Male   5000     3.5     Average
# ii. Belong to the IT department:
#    Emp_ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 1     102      Bob         IT   34   70000                    8   2017-07-19
# 2     103  Charlie         IT   41   65000                   10   2013-06-01
#
#   Gender  Bonus  Rating Performance
# 1   Male   7000     4.0        Good
# 2   Male   6000     3.8     Average

# %%
print("k) Modify the dataset by adding a new column, Tax, which deducts 10% of the Salary: ")
df2['Tax'] = df2['Salary'] * 0.1
print(df2)
# Out:
# k) Modify the dataset by adding a new column, Tax, which deducts 10% of the Salary:
#    Emp_ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0     101    Alice         HR   29   50000                    4   2020-03-15
# 1     102      Bob         IT   34   70000                    8   2017-07-19
# 2     103  Charlie         IT   41   65000                   10   2013-06-01
# 3     104    Diana  Marketing   28   55000                    3   2021-02-10
# 4     105   Edward      Sales   38   60000                   12   2010-11-25
#
#    Gender  Bonus  Rating Performance     Tax
# 0  Female   5000     4.5   Excellent  5000.0
# 1    Male   7000     4.0        Good  7000.0
# 2    Male   6000     3.8     Average  6500.0
# 3  Female   4500     4.7   Excellent  5500.0
# 4    Male   5000     3.5     Average  6000.0

# %%
# l) Save the modified DataFrame (with added columns) to a new CSV file.
df2.to_csv('modified_employees.csv', index=False)
print("Modified DataFrame saved to 'modified_employees.csv'")
# Out:
# Modified DataFrame saved to 'modified_employees.csv'
